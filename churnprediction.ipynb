# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/codebasics/deep-learning-keras-tf-tutorial/master/11_chrun_prediction/customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.drop('customerID',axis='columns', inplace=True)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
pd.to_numeric(df.TotalCharges)      # gets error because of spaces
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-45edea13cd31> in <module>()
# ----> 1 pd.to_numeric(df.TotalCharges)      # gets error because of spaces
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     151         try:
#     152             values = lib.maybe_convert_numeric(
# --> 153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#     155         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 488   Female              0     Yes  ...          52.55                  No
# 753     Male              0      No  ...          20.25                  No
# 936   Female              0     Yes  ...          80.85                  No
# 1082    Male              0     Yes  ...          25.75                  No
# 1340  Female              0     Yes  ...          56.05                  No
# 3331    Male              0     Yes  ...          19.85                  No
# 3826    Male              0     Yes  ...          25.35                  No
# 4380  Female              0     Yes  ...          20.00                  No
# 5218    Male              0     Yes  ...          19.70                  No
# 6670  Female              0     Yes  ...          73.35                  No
# 6754    Male              0      No  ...          61.90                  No
#
# [11 rows x 20 columns]

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()].shape          # number of blank values
# Out:
# (11, 20)

# %%
df.shape         # 11 out of 7k+ values are null and you can drop the values
# Out:
# (7043, 20)

# %%
df.iloc[488]
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df1 = df[df.TotalCharges != ' ']

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
# df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df2 = df1.copy()
df2['TotalCharges'] = pd.to_numeric(df1.TotalCharges)

# %%
df2.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df2.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
tenure_churn_no = df2[df2.Churn == 'No'].tenure
tenure_churn_yes = df2[df2.Churn=='Yes'].tenure

# %%
plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['churn_yes', 'churn_no'])
plt.legend()
plt.xlabel('months of tenure')
plt.ylabel('number of customers')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'number of customers')

# %%
tenure_churn_no = df2[df2.Churn == 'No'].MonthlyCharges
tenure_churn_yes = df2[df2.Churn=='Yes'].MonthlyCharges
plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['churn_yes', 'churn_no'])
plt.legend()
plt.xlabel('months of tenure')
plt.ylabel('number of customers')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'number of customers')

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df2)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df2.replace('No internet service', 'No', inplace=True)
df2.replace('No phone service', 'No', inplace=True)

# %%
print_unique_col_values(df2)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# ## convert yes and no

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']

# %%
for col in yes_no_columns:
    df2[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df2['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df3 = pd.get_dummies(df2, columns=(['InternetService', 'Contract', 'PaymentMethod']))
df3.head()
# Out:
#    gender  ...  PaymentMethod_Mailed check
# 0       1  ...                           0
# 1       0  ...                           1
# 2       0  ...                           1
# 3       0  ...                           0
# 4       1  ...                           0
#
# [5 rows x 27 columns]

# %%
df3.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
for col in df3:
    print(f'{col}: {df3[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df3[cols_to_scale] = scaler.fit_transform(df3[cols_to_scale])

# %%
for col in df3:
    print(f'{col}: {df3[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df3.drop('Churn',axis='columns')
y = df3['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 5664       1  ...                           0
# 101        1  ...                           0
# 2621       0  ...                           0
# 392        1  ...                           0
# 1327       0  ...                           0
# 3607       1  ...                           1
# 2773       0  ...                           0
# 1936       1  ...                           0
# 5387       0  ...                           0
# 4331       0  ...                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),   # same number of neurons as len(x_train.columns) = 26
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')      # it has 1 and 0
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',   # because our output is binary which is 0 and 1
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=200)     # Google colab runtime type is TPU
# Out:
# Epoch 1/200
# 176/176 [==============================] - 1s 2ms/step - loss: 0.
200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8361
# Epoch 117/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8380
# Epoch 118/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8341
# Epoch 119/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8345
# Epoch 120/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8372
# Epoch 121/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8391
# Epoch 122/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3470 - accuracy: 0.8370
# Epoch 123/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8380
# Epoch 124/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8348
# Epoch 125/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8370
# Epoch 126/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8338
# Epoch 127/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8336
# Epoch 128/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8350
# Epoch 129/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8379
# Epoch 130/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8364
# Epoch 131/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.8375
# Epoch 132/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3447 - accuracy: 0.8368
# Epoch 133/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8380
# Epoch 134/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8356
# Epoch 135/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8395
# Epoch 136/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3436 - accuracy: 0.8393
# Epoch 137/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8356
# Epoch 138/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8377
# Epoch 139/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8366
# Epoch 140/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8412
# Epoch 141/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.8352
# Epoch 142/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8357
# Epoch 143/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8380
# Epoch 144/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8412
# Epoch 145/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8368
# Epoch 146/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8388
# Epoch 147/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8370
# Epoch 148/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8382
# Epoch 149/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8407
# Epoch 150/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8412
# Epoch 151/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8407
# Epoch 152/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8404
# Epoch 153/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8400
# Epoch 154/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8434
# Epoch 155/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8411
# Epoch 156/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8405
# Epoch 157/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3398 - accuracy: 0.8407
# Epoch 158/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8398
# Epoch 159/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8425
# Epoch 160/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8407
# Epoch 161/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8409
# Epoch 162/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8418
# Epoch 163/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8414
# Epoch 164/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8427
# Epoch 165/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8420
# Epoch 166/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8437
# Epoch 167/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8464
# Epoch 168/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8404
# Epoch 169/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3335 - accuracy: 0.8414
# Epoch 170/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8421
# Epoch 171/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8396
# Epoch 172/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8452
# Epoch 173/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8416
# Epoch 174/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8425
# Epoch 175/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8441
# Epoch 176/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8421
# Epoch 177/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3316 - accuracy: 0.8446
# Epoch 178/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8425
# Epoch 179/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8437
# Epoch 180/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3304 - accuracy: 0.8425
# Epoch 181/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8427
# Epoch 182/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8434
# Epoch 183/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8450
# Epoch 184/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3288 - accuracy: 0.8468
# Epoch 185/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3286 - accuracy: 0.8455
# Epoch 186/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3307 - accuracy: 0.8453
# Epoch 187/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3296 - accuracy: 0.8430
# Epoch 188/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8457
# Epoch 189/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3269 - accuracy: 0.8450
# Epoch 190/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3275 - accuracy: 0.8453
# Epoch 191/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8475
# Epoch 192/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8452
# Epoch 193/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3273 - accuracy: 0.8453
# Epoch 194/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8471
# Epoch 195/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8475
# Epoch 196/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3247 - accuracy: 0.8491
# Epoch 197/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8464
# Epoch 198/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8464
# Epoch 199/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3249 - accuracy: 0.8478
# Epoch 200/200
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3257 - accuracy: 0.8469

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 1ms/step - loss: 0.5768 - accuracy: 0.7548
# [0.5767905712127686, 0.7547974586486816]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[2.53279507e-02],
#        [5.75821698e-01],
#        [1.06264124e-04],
#        [8.82918119e-01],
#        [4.08619285e-01]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       999
#            1       0.60      0.47      0.53       408
#
#     accuracy                           0.75      1407
#    macro avg       0.70      0.67      0.68      1407
# weighted avg       0.74      0.75      0.75      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1407,)

# %% [markdown]
# accuracy

# %%
round((871+191)/(871+191+217+128), 2)
# Out:
# 0.75

# %% [markdown]
# Precision for 0 class : customers who did not churn

# %%
round(871/(871+217),2)
# Out:
# 0.8

# %% [markdown]
# Precision for 1 class : customers who churn

# %%
round(191/(191+128),2)
# Out:
# 0.6

# %% [markdown]
# recall 0 :

# %%
round(871/(871+128),2)
# Out:
# 0.87

# %% [markdown]
# recall 1:

# %%
round(217/(217+192),2)
# Out:
# 0.53
